# %%
import os
import pandas as pd
import warnings 
import numpy as np
from matplotlib import rc, rcParams
import matplotlib.pyplot as plt

warnings.filterwarnings(action='ignore')
rc('font',family='AppleGothic')
rcParams['axes.unicode_minus']=False

# %%
path = './data_전용면적별/'

train = pd.read_csv(path+'train_new.csv')
test = pd.read_csv(path+'test_new.csv')

train.shape, test.shape
# Out:
# ((1547, 70), (567, 68))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import cross_val_score

# %%
sel = ['임대료','단지내주차면수','전용면적별세대수', '면적_세대수_곱', '면적_세대수_곱_총합','면적_세대수_비율',
      '강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
       '서울특별시', '세종특별자치시', '울산광역시', '전라남도', '전라북도', '제주특별자치도', '충청남도', '충청북도',
      '나머지', '분양상가', '분양아파트']

X = train[sel]
y = train[['전용면적_비례_차량수']]

# 피처스케일링
scaler = MinMaxScaler()# MinMaxScaler StandardScaler
X_nor = scaler.fit_transform(X)
tmp_X_nor = X_nor[:,:6]
X_poly = PolynomialFeatures(degree=2, include_bias=False).fit_transform(tmp_X_nor)  

X_all = np.concatenate((X_poly, X_nor[:,6:]), axis=1)

# 모델 
rf = RandomForestRegressor()

# 회귀는 교차검증
rf_scores = cross_val_score(rf, X_all, y,scoring='neg_mean_absolute_error', cv=5)
rf_score = np.abs(rf_scores.mean())
print("RandomForestRegressor : ", rf_score)
# Out:
# RandomForestRegressor :  34.26226160416165

# %%
X_test = test[sel]

X_test_nor = scaler.transform(X_test)
tmp_X_test_nor = X_test_nor[:,:6]
X_test_poly = PolynomialFeatures(degree=2, include_bias=False).fit_transform(tmp_X_test_nor)
X_test_all = np.concatenate((X_test_poly, X_test_nor[:,6:]), axis=1)

rf.fit(X_all, y)
pred = rf.predict(X_test_all)
print(X_test.shape)
print(pred.shape)
# Out:
# (567, 25)
# (567,)

# %%
test['전용면적_비례_차량수'] = pred
test
# Out:
#       단지코드  총세대수 임대건물구분    지역       공급유형  전용면적   공가수 자격유형       임대보증금  \
# 0    C1003   480    아파트  경상남도       행복주택    16  29.0    J  12000000.0
# 1    C1003   480    아파트  경상남도       행복주택    26  29.0    J  18800000.0
# 2    C1003   480    아파트  경상남도       행복주택    26  29.0    J  19600000.0
# 3    C1003   480    아파트  경상남도       행복주택    36  29.0    J  25600000.0
# 4    C1003   480    아파트  경상남도       행복주택    44  29.0    J  30000000.0
# ..     ...   ...    ...   ...        ...   ...   ...  ...         ...
# 562  C2688   150    아파트  전라남도       국민임대    46   1.0    H  16448000.0
# 563  C2688   150    아파트  전라남도       영구임대    24   1.0    C   9113000.0
# 564  C2688   150    아파트  전라남도       영구임대    24   1.0    C   9163000.0
# 565  C2691   765    아파트   경기도  공공임대(10년)    74  25.0    A  66000000.0
# 566  C2691   765    아파트   경기도  공공임대(10년)    84  25.0    A  80000000.0
#
#           임대료  ...  O  ERROR1_lb 나머지  분양상가  분양아파트  전용면적별세대수  면적_세대수_곱  \
# 0     61000.0  ...  0          0   1     0      0       128      2048
# 1     96000.0  ...  0          0   1     0      0        30       780
# 2    100000.0  ...  0          0   1     0      0       220      5720
# 3    131000.0  ...  0          0   1     0      0        68      2448
# 4    154000.0  ...  0          0   1     0      0        34      1496
# ..        ...  ... ..        ...  ..   ...    ...       ...       ...
# 562  194290.0  ...  0          0   1     0      0        16       736
# 563   86450.0  ...  0          0   1     0      0        26       624
# 564   86940.0  ...  0          0   1     0      0         4        96
# 565  550000.0  ...  0          0   1     0      0       175     12950
# 566  580000.0  ...  0          0   1     0      0       590     49560
#
#      면적_세대수_곱_총합  면적_세대수_비율  전용면적_비례_차량수
# 0          12492   0.163945    48.936736
# 1          12492   0.062440    20.050442
# 2          12492   0.457893   133.991280
# 3          12492   0.195965    45.078420
# 4          12492   0.119757    38.618852
# ..           ...        ...          ...
# 562         4552   0.161687    18.394930
# 563         4552   0.137083    16.751434
# 564         4552   0.021090     1.651398
# 565        62510   0.207167   223.181168
# 566        62510   0.792833   927.089024
#
# [567 rows x 69 columns]

# %%
final = test.groupby("단지코드", as_index=False).agg({'전용면적_비례_차량수': 'sum'})
final.columns = ['code', 'num']
final
# Out:
#       code          num
# 0    C1003   286.675731
# 1    C1006   421.900408
# 2    C1016   644.092412
# 3    C1019   275.492899
# 4    C1030    29.867101
# ..     ...          ...
# 142  C2646   548.855954
# 143  C2653   959.837710
# 144  C2676   345.964611
# 145  C2688   114.413484
# 146  C2691  1150.270191
#
# [147 rows x 2 columns]

# %%
err = {'code':['C2675', 'C2335', 'C1327'],
           'num':['0', '0', '0']}
err_df = pd.DataFrame(err)

final = pd.concat([final, err_df])
final.reset_index(drop=True, inplace=True)
final
# Out:
#       code      num
# 0    C1003  286.676
# 1    C1006    421.9
# 2    C1016  644.092
# 3    C1019  275.493
# 4    C1030  29.8671
# ..     ...      ...
# 145  C2688  114.413
# 146  C2691  1150.27
# 147  C2675        0
# 148  C2335        0
# 149  C1327        0
#
# [150 rows x 2 columns]

# %%
PATH = './sub/'

final.to_csv(PATH + "0727_1st_sub.csv", index=False)
os.listdir(PATH)
# Out:
# ['0727_1st_sub.csv']

# %% [markdown]
# > 결과 : 108.0523610055
